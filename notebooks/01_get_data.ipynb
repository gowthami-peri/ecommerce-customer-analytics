# %% [markdown]
# # E-Commerce Customer Analytics
#
# ## Notebook 1: Data Acquisition and Initial Exploration
#
# This notebook loads the Brazilian Olist E-Commerce dataset and performs an initial inspection of the available tables.

# %%
from pathlib import Path
import pandas as pd

# %%
PROJECT_ROOT = Path("..")

RAW_DATA_DIR = PROJECT_ROOT / "data" / "raw"
RESULTS_DIR = PROJECT_ROOT / "data" / "results"

RAW_DATA_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Dataset Overview
#
# The Olist dataset contains information about:
#
# - Customers
# - Orders
# - Order Items
# - Payments
# - Products
# - Sellers
# - Reviews
# - Geolocation
#
# These tables will be joined later for customer and revenue analysis.

# %%
customers = pd.read_csv(
    RAW_DATA_DIR / "olist_customers_dataset.csv"
)

orders = pd.read_csv(
    RAW_DATA_DIR / "olist_orders_dataset.csv"
)

order_items = pd.read_csv(
    RAW_DATA_DIR / "olist_order_items_dataset.csv"
)

payments = pd.read_csv(
    RAW_DATA_DIR / "olist_order_payments_dataset.csv"
)

products = pd.read_csv(
    RAW_DATA_DIR / "olist_products_dataset.csv"
)

reviews = pd.read_csv(
    RAW_DATA_DIR / "olist_order_reviews_dataset.csv"
)

sellers = pd.read_csv(
    RAW_DATA_DIR / "olist_sellers_dataset.csv"
)

# %%
datasets = {
    "customers": customers,
    "orders": orders,
    "order_items": order_items,
    "payments": payments,
    "products": products,
    "reviews": reviews,
    "sellers": sellers
}

for name, df in datasets.items():
    print(f"{name}: {df.shape}")
# Out:
# customers: (99441, 5)
# orders: (99441, 8)
# order_items: (112650, 7)
# payments: (103886, 5)
# products: (32951, 9)
# reviews: (99224, 7)
# sellers: (3095, 4)
